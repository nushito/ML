# %%
# %matplotlib inline

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 

from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier
from sklearn.ensemble import VotingClassifier, StackingClassifier

# %%
log_reg = LogisticRegression() # може и SGDClassifier(loss = "hinge")

# %%
log_regrs = [(f"log_reg_{i}",LogisticRegression()) for i in range(20)]

# %%
voting = VotingClassifier(log_regrs) # za по-сложен модел ползваме Stackingclassifier

# %%
vote_cls = [(f"vote_cl_{i}",VotingClassifier(log_regrs)) for i in range(5)]

# %%
StackingClassifier(vote_cls)
# Out:
# StackingClassifier(estimators=[('vote_cl_0',
#                                 VotingClassifier(estimators=[('log_reg_0',
#                                                               LogisticRegression()),
#                                                              ('log_reg_1',
#                                                               LogisticRegression()),
#                                                              ('log_reg_2',
#                                                               LogisticRegression()),
#                                                              ('log_reg_3',
#                                                               LogisticRegression()),
#                                                              ('log_reg_4',
#                                                               LogisticRegression()),
#                                                              ('log_reg_5',
# ...

# %%
units =[(f"sgd_cl_{i}",SGDClassifier(loss = "hinge")) for i in range(20)]

# %%
layers = VotingClassifier(units)

# %%
nn = [(f"vote_cl_{i}",VotingClassifier(layers)) for i in range(5)]

# %%
nn
# Out:
# [('vote_cl_0',
#   VotingClassifier(estimators=VotingClassifier(estimators=[('sgd_cl_0',
#                                                             SGDClassifier()),
#                                                            ('sgd_cl_1',
#                                                             SGDClassifier()),
#                                                            ('sgd_cl_2',
#                                                             SGDClassifier()),
#                                                            ('sgd_cl_3',
#                                                             SGDClassifier()),
#                                                            ('sgd_cl_4',
#                                                             SGDClassifier()),
#                                                            ('sgd_cl_5',
#                                                             SGDClassifier()),
# ...

# %%
StackingClassifier(nn)
# Out:
# StackingClassifier(estimators=[('vote_cl_0',
#                                 VotingClassifier(estimators=VotingClassifier(estimators=[('sgd_cl_0',
#                                                                                           SGDClassifier()),
#                                                                                          ('sgd_cl_1',
#                                                                                           SGDClassifier()),
#                                                                                          ('sgd_cl_2',
#                                                                                           SGDClassifier()),
#                                                                                          ('sgd_cl_3',
#                                                                                           SGDClassifier()),
# ...
